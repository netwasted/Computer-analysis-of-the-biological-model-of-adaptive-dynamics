# %% [markdown]
# # Двухвидовой CCTO. Численный метод #

# %% [markdown]
# # Одномерный случай #

# %%
fig = plt.figure(figsize=(15, 12))
x,y,z = np.loadtxt("/Users/Anastasia/Documents/project/PLOT_DATA/plot1_2sp_1d_old.txt", unpack=True)

ax = fig.gca(projection='3d')
ax.set_xlabel('SM2')
ax.set_ylabel('D12')
ax.set_zlabel('First moment')
surf = ax.plot_trisurf(x, y, z, cmap=cm.jet, linewidth=0.2, antialiased=True)

x,y,z = np.loadtxt("/Users/Anastasia/Documents/project/PLOT_DATA/plot2_2sp_1d_old.txt", unpack=True)

surf = ax.plot_trisurf(x, y, z, cmap=cm.jet, linewidth=0.2, antialiased=True)
plt.colorbar(surf, shrink=0.5, aspect=5)
ax.set_title('ССТО 1D 2 species')
plt.show()

# %% [markdown]
# # Двумерный случай #

# %%
fig = plt.figure(figsize=(15, 12))
x,y,z = np.loadtxt("/Users/Anastasia/Documents/project/PLOT_DATA/plot1_2sp_2d_old.txt", unpack=True)

ax = fig.gca(projection='3d')
ax.set_xlabel('SM2')
ax.set_ylabel('D12')
ax.set_zlabel('First moment')
surf = ax.plot_trisurf(x, y, z, cmap=cm.jet, linewidth=0.2, antialiased=True)

x,y,z = np.loadtxt("/Users/Anastasia/Documents/project/PLOT_DATA/plot2_2sp_2d_old.txt", unpack=True)

surf = ax.plot_trisurf(x, y, z, cmap=cm.jet, linewidth=0.2, antialiased=True)
plt.colorbar(surf, shrink=0.5, aspect=5)
ax.set_title('ССТО 2D 2 species')
plt.show()

# %% [markdown]
# # Трехмерный случай #

# %%
fig = plt.figure(figsize=(15, 12))
x,y,z = np.loadtxt("/Users/Anastasia/Documents/project/PLOT_DATA/plot1_2sp_3d_old.txt", unpack=True)

ax = fig.gca(projection='3d')
ax.set_xlabel('SM2')
ax.set_ylabel('D12')
ax.set_zlabel('First moment')
surf = ax.plot_trisurf(x, y, z, cmap=cm.jet, linewidth=0.2, antialiased=True)

x,y,z = np.loadtxt("/Users/Anastasia/Documents/project/PLOT_DATA/plot2_2sp_3d_old.txt", unpack=True)

surf = ax.plot_trisurf(x, y, z, cmap=cm.jet, linewidth=0.2, antialiased=True)
plt.colorbar(surf, shrink=0.5, aspect=5)
ax.set_title('ССТО 3D 2 species')
plt.show()

# %% [markdown]
# # Двухвидовая HM #

# %% [markdown]
# # Одномерный случай #

# %%
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits import mplot3d
import matplotlib.pyplot as plt
from matplotlib import cm
import numpy as np
from sys import argv

fig = plt.figure(figsize=(15, 12))
x,y,z = np.loadtxt("/Users/Anastasia/Documents/project/PLOT_DATA/plot1_hm_1d.txt", unpack=True)

ax = fig.gca(projection='3d')
ax.set_xlabel('SW11=SW22')
ax.set_ylabel('SW12=SW21')
ax.set_zlabel('First moment')
surf = ax.plot_trisurf(x, y, z, cmap=cm.jet, linewidth=0.2, antialiased=True)

x,y,z = np.loadtxt("/Users/Anastasia/Documents/project/PLOT_DATA/plot2_hm_1d.txt", unpack=True)

surf = ax.plot_trisurf(x, y, z, cmap=cm.jet, linewidth=0.2, antialiased=True)
plt.colorbar(surf, shrink=0.5, aspect=5)
ax.set_title('HM 1D 2 species')
plt.show()

# %% [markdown]
# # Двумерный случай #

# %%
fig = plt.figure(figsize=(15, 12))
x,y,z = np.loadtxt("/Users/Anastasia/Documents/project/PLOT_DATA/plot1_hm_2d.txt", unpack=True)

ax = fig.gca(projection='3d')
ax.set_xlabel('SW11=SW22')
ax.set_ylabel('SW12=SW21')
ax.set_zlabel('First moment')
surf = ax.plot_trisurf(x, y, z, cmap=cm.jet, linewidth=0.2, antialiased=True)

x,y,z = np.loadtxt("/Users/Anastasia/Documents/project/PLOT_DATA/plot2_hm_2d.txt", unpack=True)

surf = ax.plot_trisurf(x, y, z, cmap=cm.jet, linewidth=0.2, antialiased=True)
plt.colorbar(surf, shrink=0.5, aspect=5)
ax.set_title('HM 2D 2 species')
plt.show()

# %% [markdown]
# # Трехмерный случай #

# %%
fig = plt.figure(figsize=(15, 12))
x,y,z = np.loadtxt("/Users/Anastasia/Documents/project/PLOT_DATA/plot1_hm_3d.txt", unpack=True)

ax = fig.gca(projection='3d')
ax.set_xlabel('SW11=SW22')
ax.set_ylabel('SW12=SW21')
ax.set_zlabel('First moment')
surf = ax.plot_trisurf(x, y, z, cmap=cm.jet, linewidth=0.2, antialiased=True)

x,y,z = np.loadtxt("/Users/Anastasia/Documents/project/PLOT_DATA/plot2_hm_3d.txt", unpack=True)

surf = ax.plot_trisurf(x, y, z, cmap=cm.jet, linewidth=0.2, antialiased=True)
plt.colorbar(surf, shrink=0.5, aspect=5)
ax.set_title('HM 3D 2 species')
plt.show()
